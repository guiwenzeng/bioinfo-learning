# %% [markdown]
# In Bioinformatics, Python is used for:
# 1. DNA/RNA sequence analysis
# 2. Protein analysis
# 3. Genomics
# 4. Transcriptomics (RNA-seq)
# 5. Single-cell sequencing
# 6. Machine learning in biology
# 7. Data visualization

# %% [markdown]
# Python Data Science Ecosystem
#
# Raw Biological Data
#        │
#        ▼
#      Python
#        │
# ┌──────┼────────┐
# ▼      ▼        ▼
# NumPy Pandas Matplotlib
# │      │        │
# Matrix Tables Figures
# │
# ▼
# Machine Learning
# │
# ▼
# Biological Discovery

# %% [markdown]
# Numpy >>> Numerival computing, fast array, and matrix operations
# Common uses: gene expression matrices, statistical calculations, mathematical operations

# %%
import numpy as np
arr = np.array([1,2,3])

# %% [markdown]
# Pandas >>> Data Manipulation
# CSV files, Excel files, Patient information, Gene expression tables

# %%
import pandas as pd
df = pd.read_csv("gene_expression.csv")

# %% [markdown]
# Matplotlib >>> Data Visualization
# Common uses: scatter plots, histograms, bar charts, heatmaps

# %%
import matplotlib.pyplot as plt

# %%
variables store information;
gene = "TP53"
expression = 12.8

data type;
int (integer) float (decimal number) str (text) bool (boolean)

conditional statements use if to make decisions based on conditions;
if gc_context > 50:
    print("High GC")
else:
    Print("Low GC")

for Loop;
Very common in bioinformatics because DNA sequences are processed on base at a time.
    sequence ="ATCG"
for base in sequence:
    print(base)

Functions package reusable code;
def gc_content(sequence):
    # Calculate GC content
    gc = sequence.count("G") + sequence.count("C")
    return gc / len(sequence)

# %%
List: Ordered and mutable.
    genes = ["TP53","EGFR","BRCA1"]
    gene.append("KRA")

Tuple: Ordered but immutable.
    chromosome=("chr1","chr2","chr3")

Dictionary: Key-value pairs.
    expression = {"TP53":5.6, "EGFR":8.1}

Set: store unique values only, useful for removing duplicates. 
    genes = {"TP53", "EGFR", "TP53"}
print(gene)
Output: {'TP53','EGFR'}

# %%
length = []
for gene in genes:
    length.append(len(gene))
List comprehension: length = [len(gene) for gene in genes]

# %%
Read a file 
with open("dna.txt","r")as file:
dna = file.read()

Write a file
with open("result.txt","w")as file:
    file.write("Analysis Complete")
